# %% [markdown]
# #The following code demonstrates the training of the thalamus SNN on the Fashion MNIST dataset

# %% [markdown]
# ##Importing relevant libraries

# %%
# !pip install snntorch  # snnTorch is not pre-installed on Google Colab or local IDEs. Hence, needs to be installed manually.
# !pip install torch torchvision  # PyTorch is pre-installed on Google Colab but not on most local IDEs. Install manually if using locally.
# Out:
# Collecting snntorch
#   Downloading snntorch-1.0.0-py2.py3-none-any.whl.metadata (15 kB)
# Downloading snntorch-1.0.0-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.6/133.6 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: snntorch
# Successfully installed snntorch-1.0.0

# %%
# For loading the Dataset and creating DataLoaders:
from torch.utils.data import DataLoader, random_split, ConcatDataset
from torchvision import datasets, transforms

# For network connectivity maps and tensor operations
import torch
import torch.nn as nn

# For Leaky Integrate-and-Fire (LIF) neuron models
import snntorch as snn

# For plotting
import matplotlib.pyplot as plt
import itertools

# For numeric arrays and defining poisson noise
import numpy as np
import random

# For hardware and software specifications
import platform
import psutil
import pandas as pd

# Uncomment the lines below to save the model to Google Drive
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ##Getting static MNIST dataset

# %% [markdown]
# We pass 128 images to the model at a time.

# %%
batch_size = 128 # Number of images passed at a time to the model (used in DataLoader below).
dtype = torch.float # Data type for tensors

# %%
data_path='/tmp/data/fashion-mnist' # Path to download/store the Fashion-MNIST dataset

# %% [markdown]
# ##Applying transforms to the images

# %% [markdown]
# In this work, each image is normalised such that the mean (µ) and standard deviation (σ) of the pixel values are 0 and 1 respectively.

# %%
# Except for ".ToTensor()", these transforms are unnecessary for F-MNIST images.
transform = transforms.Compose([
            transforms.Resize((28, 28)), # Redundant: Resizes images to 28 x 28 pixels.
            transforms.Grayscale(), # Redundant: If image has 3 channels (RGB), this makes it single channel (grayscale).
            transforms.ToTensor(), # Required: Converts PIL image to a PyTorch tensor and scales pixel values to [0, 1].
            transforms.Normalize((0,), (1,))]) # Redundant: Normalizes the image tensor to have a specific mean (0) and standard deviation (1) for each channel.

# %% [markdown]
# ## Dividing the data into a 70 : 30 ratio such that there were 49,000 and 21,000 images respectively for training and testing.

# %%
# Fetching training and testing data and concatenating these datasets to perform a custom split:

# Dataset stores the samples of images and their corresponding labels, using the default train-test split
train_data = datasets.FashionMNIST(data_path, train=True, download=True, transform=transform)
test_data = datasets.FashionMNIST(data_path, train=False, download=True, transform=transform)

full_dataset = ConcatDataset([train_data, test_data ]) # Concatenates train and test to get full dataset.
total_size = len(full_dataset)  # No. of images in full dataset: 70,000

# Re-split full dataset into 70% training (49,000) and 30% test (21,000)
train_size = int(0.7 * total_size)
test_size = total_size - train_size

# random_split (from torch.utils.data) randomly divides full_dataset based on above train_size and test_size.
# Note: random_split does not preserve class distribution (i.e., not stratified).
train_, test_ = random_split(full_dataset, [train_size, test_size])
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 10.5MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 162kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.02MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 9.91MB/s]

# %%
# DataLoader creates an iterable shuffled batches of the dataset and drops incomplete batches
train_loader = DataLoader(train_, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(test_, batch_size=batch_size, shuffle=True, drop_last=True)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# ![Figure 1 with output Layer.png](data:image/png;base64,...)

# %%
duration=0.025  # Total simulation time in milliseconds (ms) i.e each iteration runs for 25ms
dt = 0.001    # A single time step is a millisecond
num_steps=int(duration/dt) # Total number of time steps is 25ms

# %% [markdown]
# ##Defining the 4 neuron populations (a total of 832 neurons)

# %%
neurons=int(0.6*784) #Scaling the number of neurons down to 60% for sparsity, to mimic the sparsity of the brain
input_neurons = 784 #as there are 784 pixels in an image

# Ratio TCR:TRN:IN is 4:2:1. These ratios and the nature of the neuron populations of the LGN are as per
# Sen Bhattacharya et al., “A spiking neural network model of the lateral geniculate nucleus on the SpiNNaker machine”
tcr_neurons = neurons
trn_neurons = int(neurons / 2)
in_neurons = int(neurons / 4)
output_neurons=10 # Since there are 10 output classes in the case of FMNIST

# %% [markdown]
# ##Defining the network

# %%
#Define Network
class Net(nn.Module):
    def __init__(self, input_neurons, tcr_neurons, trn_neurons, in_neurons):
        super(Net, self).__init__()
        # Initializes layers. Performs linear transformation on input data
        # y=xW^T+b where y is output, x is input, W^T is transpose of weight matrix. Bias (b) is not included here.
        self.fc1 = nn.Linear(input_neurons,tcr_neurons, bias=False)
        self.fc2 = nn.Linear(input_neurons, in_neurons, bias=False)
        self.fc3 = nn.Linear(in_neurons, tcr_neurons, bias=False)
        self.fc4 = nn.Linear(in_neurons, in_neurons, bias=False)
        self.fc5 = nn.Linear(tcr_neurons, trn_neurons, bias=False)
        self.fc6 = nn.Linear(trn_neurons, tcr_neurons, bias=False)
        self.fc7 = nn.Linear(trn_neurons, trn_neurons, bias=False)
        self.fc8 = nn.Linear(tcr_neurons, output_neurons, bias=False)

        # Beta values of the LIFs were set heuristically. Default threshold is used i.e 1. Beta and Threshold are kept as learnable parameters.
        # Default reset mechanism i.e reset by subtraction is used, wherein every time that a spike is generated at time t, the membrane potential is set back by an amount θ at the next time instant t+1
        self.lif1 = snn.Leaky(beta=0.95, learn_beta=True, learn_threshold=True) #in
        self.lif2 = snn.Leaky(beta=0.9, learn_beta=True, learn_threshold=True) #tcr
        self.lif3 = snn.Leaky(beta=0.9, learn_beta=True, learn_threshold=True) #trn
        self.lif4 = snn.Leaky(beta=0.9, learn_beta=True, learn_threshold=True) #output

        #Initial membrane potential kept as 1
        self.mem1 = torch.ones(1)
        self.mem2 = torch.ones(1)
        self.mem3 = torch.ones(1)
        self.mem4 = torch.ones(1)
        self.spk4 = torch.ones(1)


    #FORWARD PASS
    def forward(self,flattened_images):
      spike_in=flattened_images #Plain pixel intensity values

      # Initial dummy value inputs needed for self-loop connectivities of TRN and IN
      spk2 = torch.zeros(trn_neurons)
      spk3 = torch.zeros(in_neurons)

      # Initialize tensors to store membrane potentials and spikes of output layer over time
      full_mem=torch.zeros(num_steps, batch_size, output_neurons)
      full_spk=torch.zeros(num_steps, batch_size, output_neurons)



      # NETWORK SIMULATION: Iterates over 128 images (1 batch) for 25 time steps (25ms) each
      for step in range(num_steps):
          # IN layer: Receives image input, self input
          cur3 = self.fc2(spike_in) + self.fc4(spk3)
          spk3, self.mem3 = self.lif1(cur3, self.mem3)

          # TCR layer: Receives image input, TRN and IN feedback
          cur1 = self.fc1(spike_in) + self.fc6(spk2) + self.fc3(spk3)
          spk1, self.mem1 = self.lif2(cur1, self.mem1)

          # TRN layer: Receives TCR and TRN feedback
          cur2 = self.fc5(spk1) + self.fc7(spk2)
          spk2, self.mem2 = self.lif3(cur2, self.mem2)

          # OUTPUT layer: Receives TCR input
          cur4 = self.fc8(spk1)
          self.spk4, self.mem4 = self.lif4(cur4, self.mem4)

          # Record outputs
          full_mem[step] =  self.mem4
          full_spk[step] = self.spk4
      #The shape of the recorded output will be (25,128,10) i.e (num_steps, batch size, output layer neurons). Test by uncommenting the line below.
      #print("full_mem.size:",full_mem.size())
      return full_mem, full_spk

# %% [markdown]
# ## Instantiating model

# %%
device = torch.device("cuda") # Sets the device to GPU (CUDA), assuming CUDA is available

# Instantiate model
model = Net(input_neurons, tcr_neurons, trn_neurons, in_neurons)

# Weight Clamping: To keep the weights of inhibitory connections negative and those of excitatory connections positive.
upperlim=2.0 #excitatory weights stay below 2
lowerlim=-2.0 #inhibitory weights stay above -2
mid=0.0 #excitatory weights stay above 0, inhibitory weights stay below 0

for name, param in model.named_parameters():
  if "fc3" in name or "fc4" in name  or "fc6" in name  or "fc7" in name:  #inhibitory connectivities
      param.data.clamp_(min=lowerlim, max=mid)
  elif "fc1" in name or "fc2" in name  or "fc5" in name: #excitatory connectivities
      param.data.clamp_(min=mid, max=upperlim)
  elif "fc8" in name: #tcr to output. A connectivity that's not purely excitatory showed better results.
    param.data.clamp_(min=lowerlim, max=upperlim)
  if "fc4" in name or "fc7" in name:
    param.data.fill_diagonal_(0) #Giving self-loop weight matrices zero diagonal so neurons don't receive their own output as input.

# %%
#Uncomment the line below to view the initial weights
#print(f"fc1:{model.fc1.weight},\nfc2:{model.fc2.weight},\nfc3:{model.fc3.weight},\nfc4:{model.fc4.weight},\nfc5:{model.fc5.weight},\nfc6:{model.fc6.weight},\nfc7:{model.fc7.weight},\nfc8:{model.fc8.weight}")
#Uncomment the line below to save the initial weights
#torch.save(model.state_dict(), "/content/drive/My Drive/Initial.pth")

# %% [markdown]
# ## Defining the optimizer and loss function: Adam optimizer and Cross Entropy Loss function

# %%
# The Adam optimizer adaptively updates the model's parameters (weights and biases) using gradients from backpropagation to minimize the loss function during training.
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4, betas=(0.9, 0.999)) # Parameters are as per snnTorch Tutorial 5: https://snntorch.readthedocs.io/en/latest/tutorials/tutorial_5.html

# Loss function, using log, measures the difference between the predicted outputs of the model and the true target values.
loss = nn.CrossEntropyLoss()

# %% [markdown]
# ## Accuracy calculation for each iteration within an epoch

# %%
def print_batch_accuracy(data, targets, train=False):
    #Forward pass
    _,output = model(data)  # Pass data to model. 'output' holds spikes (full_spk).

    _, idx = output.sum(dim=0).max(1)  # Sums up spikes over time steps, then finds the index of neuron with maximum spikes to get the predicted class.

    # Calculate accuracy by comparing predictions with actual targets.
    acc = (targets == idx).float().mean().item() # gives mean of a boolean tensor where 1=>True and 0=>False

    # Prints results as percentage
    if train:
        print(f"Train set accuracy for a single minibatch: {acc*100:.2f}%")
        accuracy_train[epoch][iter_counter] =(acc*100)
    else:
        print(f"Test set accuracy for a single minibatch: {acc*100:.2f}%")
        accuracy_test[epoch][iter_counter] =(acc*100)

# %% [markdown]
# ##Function to display progress of training and display weights during training

# %%
def train_printer(data, targets, epoch,  iter_counter, loss_hist, test_loss_hist, test_data, test_targets):
    # Prints accuracy and loss at intervals during training.
    print(f"Epoch {epoch}, Iteration {iter_counter}")
    print(f"Train Set Loss: {loss_hist[epoch][iter_counter]:.2f}")
    print(f"Test Set Loss: {test_loss_hist[epoch][iter_counter]:.2f}")

    print(f"fc1:{model.fc1.weight},\nfc2:{model.fc2.weight},\nfc3:{model.fc3.weight},\nfc4:{model.fc4.weight},\nfc5:{model.fc5.weight},\nfc6:{model.fc6.weight},\nfc7:{model.fc7.weight},\nfc8:{model.fc8.weight}")
    print("\n")

# %% [markdown]
# ##Training Loop: Runs for 5 epochs of 380 iterations each

# %% [markdown]
# The training loop ends after 5 epochs as the loss curve appears to stabilize at that point.
# Within each iteration we train on 128 images for 25ms each.

# %%
batches= 380 # Number of batches to train on.
num_epochs = 5 # Can be varied but the loss curve appears to stabilize at 5 epochs.
num_iterations = batches

# Data structures for plotting:
loss_hist = np.full((num_epochs, num_iterations), np.nan, dtype=float)
test_loss_hist = np.full((num_epochs, num_iterations), np.nan, dtype=float)
accuracy_train=np.full((num_epochs, num_iterations), np.nan, dtype=float)
accuracy_test= np.full((num_epochs, num_iterations), np.nan, dtype=float)

# TRAINING LOOP
for epoch in range(num_epochs):
    iter_counter = 0 # Local iteration counter (resets every epoch).
    train_batch = iter(train_loader)

    # Minibatch training loop
    for data, targets in train_batch: # No. of loops = No. of batches
        print(f"Epoch {epoch}, Iteration {iter_counter}:\n")
        data = data
        targets = targets
        print("data size:", data.size()) # Shape must be: [128, 1, 28, 28]
        model.train() # Set model to training mode

        # Call forward pass
        mem_rec,_ = model(data.view(batch_size, -1))
        print("mem_rec (model output) size:",mem_rec.size()) # Shape must be [25, 128, 10]
        print("targets size:", targets.size()) # Shape must be equal to batch size i.e 128

        # Training Loss
        loss_val = torch.zeros((1), dtype=dtype) # Stores loss of a batch.
        for step in range(num_steps):
            loss_val += loss(mem_rec[step], targets)

        # Backpropgation
        optimizer.zero_grad() # Clears previous gradients
        loss_val.backward() # Computes the gradients of the loss function with respect to each model parameter using autograd.

        for name, param in model.named_parameters(): # Checks for gradient errors. If either statement is printed, try varying LIF parameters.
          if param.grad is None:
              print(f"{name} gradient is None!")
          elif param.grad.norm().item()==0:
              print(f"{name} gradient norm is zero.")

        optimizer.step() # Updates model parameters based on gradients

        # Weight Clamping:
        for name, param in model.named_parameters():
          if "fc3" in name or "fc4" in name  or "fc6" in name  or "fc7" in name:
              param.data.clamp_(min=lowerlim, max=mid)
          elif "fc1" in name or "fc2" in name  or "fc5" in name:
              param.data.clamp_(min=mid, max=upperlim)
          elif  "fc8" in name:
              param.data.clamp_(min=lowerlim, max=upperlim)
          if "fc4" in name or "fc7" in name:
              param.data.fill_diagonal_(0)

        # Stores loss history
        loss_hist[epoch][iter_counter] = loss_val.item()

        # Validation testing
        with torch.no_grad(): # Disables gradients.
            model.eval() # Sets model to testing mode
            test_data, test_targets = next(iter(test_loader)) # Tests the same batch at every iteration of the loop
            test_data = test_data
            test_targets = test_targets

            # Call forward pass
            test_mem, _ = model(test_data.view(batch_size, -1))

            # Validation Testing loss
            test_loss = torch.zeros((1), dtype=dtype)
            for step in range(num_steps):
                test_loss += loss(test_mem[step], test_targets)
            test_loss_hist[epoch][iter_counter] = test_loss.item()

            # Print train and test loss, accuracy
            print_batch_accuracy(data.view(batch_size, -1), targets, train=True)
            print_batch_accuracy(test_data.view(batch_size, -1), test_targets, train=False)
            if iter_counter==0 or iter_counter==batches*0.25 or iter_counter==batches*0.5 or iter_counter==batches*0.75 or iter_counter==batches-1: #printing weights after forward pass on last image in batch
                train_printer(data,targets,epoch,iter_counter,loss_hist,test_loss_hist,test_data, test_targets)

        print("---------------------------------------------------------------------------------------------------------------------------------------------------------------")
        iter_counter +=1
        if iter_counter==batches:
          break
    print("====================================================================================================================================================================")
# Out:
# Streaming output truncated to the last 5000 lines.
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.00%
# Test set accuracy for a single minibatch: 70.31%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 224:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 70.31%
# Test set accuracy for a single minibatch: 70.31%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 225:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 62.50%
# Test set accuracy for a single minibatch: 72.66%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 226:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 81.25%
# Test set accuracy for a single minibatch: 69.53%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 227:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.09%
# Test set accuracy for a single minibatch: 63.28%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 228:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 65.62%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 229:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.09%
# Test set accuracy for a single minibatch: 71.88%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 230:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.09%
# Test set accuracy for a single minibatch: 65.62%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 231:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 72.66%
# Test set accuracy for a single minibatch: 76.56%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 232:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.78%
# Test set accuracy for a single minibatch: 69.53%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 233:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 77.34%
# Test set accuracy for a single minibatch: 75.00%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 234:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 67.19%
# Test set accuracy for a single minibatch: 78.12%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 235:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 76.56%
# Test set accuracy for a single minibatch: 76.56%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 236:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 78.12%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 237:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 78.91%
# Test set accuracy for a single minibatch: 67.97%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 238:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 64.84%
# Test set accuracy for a single minibatch: 67.19%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 239:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 69.53%
# Test set accuracy for a single minibatch: 75.78%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 240:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 70.31%
# Test set accuracy for a single minibatch: 67.19%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 241:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 77.34%
# Test set accuracy for a single minibatch: 71.88%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 242:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.78%
# Test set accuracy for a single minibatch: 68.75%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 243:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.09%
# Test set accuracy for a single minibatch: 72.66%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 244:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.09%
# Test set accuracy for a single minibatch: 75.78%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 245:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 70.31%
# Test set accuracy for a single minibatch: 73.44%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 246:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 78.91%
# Test set accuracy for a single minibatch: 75.78%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 247:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 77.34%
# Test set accuracy for a single minibatch: 73.44%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 248:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 67.97%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 249:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 67.97%
# Test set accuracy for a single minibatch: 71.09%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 250:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 67.19%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 251:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 68.75%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 252:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 69.53%
# Test set accuracy for a single minibatch: 80.47%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 253:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 78.12%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 254:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 81.25%
# Test set accuracy for a single minibatch: 80.47%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 255:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 74.22%
# Test set accuracy for a single minibatch: 75.00%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 256:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.78%
# Test set accuracy for a single minibatch: 71.88%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 257:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 67.97%
# Test set accuracy for a single minibatch: 78.91%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 258:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 77.34%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 259:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 80.47%
# Test set accuracy for a single minibatch: 70.31%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 260:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.00%
# Test set accuracy for a single minibatch: 74.22%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 261:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 78.91%
# Test set accuracy for a single minibatch: 75.78%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 262:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 77.34%
# Test set accuracy for a single minibatch: 70.31%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 263:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 67.97%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 264:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 70.31%
# Test set accuracy for a single minibatch: 67.97%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 265:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.09%
# Test set accuracy for a single minibatch: 73.44%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 266:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 72.66%
# Test set accuracy for a single minibatch: 72.66%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 267:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.78%
# Test set accuracy for a single minibatch: 70.31%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 268:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 72.66%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 269:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 78.91%
# Test set accuracy for a single minibatch: 72.66%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 270:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.00%
# Test set accuracy for a single minibatch: 76.56%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 271:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 78.91%
# Test set accuracy for a single minibatch: 65.62%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 272:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.09%
# Test set accuracy for a single minibatch: 78.12%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 273:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 72.66%
# Test set accuracy for a single minibatch: 67.19%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 274:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.78%
# Test set accuracy for a single minibatch: 73.44%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 275:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.09%
# Test set accuracy for a single minibatch: 69.53%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 276:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.00%
# Test set accuracy for a single minibatch: 70.31%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 277:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.78%
# Test set accuracy for a single minibatch: 67.97%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 278:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 67.19%
# Test set accuracy for a single minibatch: 70.31%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 279:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 76.56%
# Test set accuracy for a single minibatch: 79.69%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 280:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 81.25%
# Test set accuracy for a single minibatch: 68.75%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 281:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 80.47%
# Test set accuracy for a single minibatch: 75.00%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 282:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 76.56%
# Test set accuracy for a single minibatch: 78.12%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 283:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 78.91%
# Test set accuracy for a single minibatch: 79.69%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 284:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.00%
# Test set accuracy for a single minibatch: 75.00%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 285:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 81.25%
# Test set accuracy for a single minibatch: 67.19%
# Epoch 3, Iteration 285
# Train Set Loss: 13.90
# Test Set Loss: 19.58
# fc1:Parameter containing:
# tensor([[1.5779e-02, 5.6583e-03, 0.0000e+00,  ..., 0.0000e+00, 4.7384e-04,
#          1.7643e-05],
#         [2.6948e-02, 1.3839e-02, 5.9563e-04,  ..., 5.1535e-02, 5.9360e-02,
#          2.9753e-02],
#         [8.2917e-03, 3.4044e-02, 6.0262e-02,  ..., 8.2699e-02, 1.0210e-01,
#          4.3706e-02],
#         ...,
#         [3.1024e-02, 1.2482e-02, 2.1937e-03,  ..., 3.0770e-02, 1.1791e-04,
#          3.3139e-03],
#         [4.8594e-03, 1.1055e-02, 0.0000e+00,  ..., 5.6273e-04, 3.9375e-04,
#          1.9068e-04],
#         [1.9042e-02, 3.4355e-02, 2.0075e-02,  ..., 0.0000e+00, 0.0000e+00,
#          3.9124e-03]], requires_grad=True),
# fc2:Parameter containing:
# tensor([[0.0463, 0.0309, 0.0072,  ..., 0.0333, 0.0736, 0.0260],
#         [0.0047, 0.0000, 0.0003,  ..., 0.0015, 0.0032, 0.0041],
#         [0.0071, 0.0081, 0.0001,  ..., 0.0559, 0.0261, 0.0009],
#         ...,
#         [0.0221, 0.0305, 0.0135,  ..., 0.0061, 0.0260, 0.0257],
#         [0.0000, 0.0190, 0.0368,  ..., 0.0330, 0.0330, 0.0004],
#         [0.0000, 0.0048, 0.0032,  ..., 0.0516, 0.0356, 0.0665]],
#        requires_grad=True),
# fc3:Parameter containing:
# tensor([[-4.3891e-02, -4.9515e-02, -1.1957e-03,  ..., -3.5730e-03,
#          -7.7114e-04, -4.9260e-03],
#         [-1.4974e-04, -7.7915e-03, -4.1464e-04,  ..., -1.3756e-03,
#          -5.8957e-02, -3.2613e-04],
#         [-9.8507e-03, -4.9515e-03, -1.2116e-02,  ..., -2.5414e-02,
#          -4.0623e-02, -1.7681e-02],
#         ...,
#         [-3.9467e-02, -2.1923e-02, -2.8039e-02,  ..., -4.1447e-03,
#          -5.2180e-03, -4.8548e-03],
#         [-6.6224e-02, -7.8976e-03, -4.7162e-04,  ..., -6.8900e-02,
#          -4.9209e-04, -1.5902e-02],
#         [-2.9250e-02, -6.3578e-02, -4.4387e-03,  ..., -2.1734e-07,
#          -4.2713e-02, -1.0477e-02]], requires_grad=True),
# fc4:Parameter containing:
# tensor([[ 0.0000e+00, -5.9083e-02,  0.0000e+00,  ..., -8.5703e-02,
#          -1.0901e-02, -1.9547e-02],
#         [-7.0469e-03,  0.0000e+00, -3.8730e-02,  ..., -2.5455e-02,
#          -1.6774e-02, -9.0459e-02],
#         [-2.7078e-03, -3.0605e-02,  0.0000e+00,  ..., -6.9908e-02,
#          -2.4929e-02, -1.2472e-02],
#         ...,
#         [-4.9120e-02, -7.5900e-02, -5.5038e-02,  ...,  0.0000e+00,
#           0.0000e+00, -2.0731e-05],
#         [-3.9340e-02, -7.7292e-03, -6.5435e-02,  ..., -1.6247e-02,
#           0.0000e+00, -5.1095e-02],
#         [-2.7967e-03, -5.6447e-02, -1.4043e-03,  ..., -5.9688e-02,
#          -2.2504e-02,  0.0000e+00]], requires_grad=True),
# fc5:Parameter containing:
# tensor([[6.4917e-03, 3.3757e-02, 1.8040e-02,  ..., 1.6578e-02, 2.5878e-02,
#          4.2847e-02],
#         [3.0413e-02, 3.4752e-02, 2.3508e-02,  ..., 5.0369e-02, 7.4405e-05,
#          4.2918e-03],
#         [2.6702e-04, 1.7330e-04, 2.9478e-03,  ..., 8.3918e-03, 6.1655e-05,
#          9.3628e-03],
#         ...,
#         [7.6506e-04, 5.6895e-02, 5.4979e-02,  ..., 2.6468e-02, 2.0605e-02,
#          2.1886e-03],
#         [2.8968e-03, 3.2406e-02, 2.3609e-02,  ..., 3.6756e-02, 9.8324e-03,
#          0.0000e+00],
#         [7.3507e-03, 4.7543e-03, 3.9975e-02,  ..., 2.5408e-03, 4.9269e-02,
#          1.9349e-02]], requires_grad=True),
# fc6:Parameter containing:
# tensor([[-0.0057, -0.0071,  0.0000,  ..., -0.0033, -0.0033, -0.0519],
#         [-0.0003, -0.0174, -0.0115,  ..., -0.0010, -0.0052, -0.0095],
#         [-0.0080, -0.0099, -0.0746,  ..., -0.0081, -0.0088, -0.0368],
#         ...,
#         [-0.0111, -0.0513, -0.0030,  ..., -0.0018, -0.0047, -0.0022],
#         [-0.0012, -0.0085, -0.0193,  ..., -0.0417, -0.0380, -0.0466],
#         [-0.0002, -0.0089, -0.0081,  ..., -0.0598, -0.0002, -0.0174]],
#        requires_grad=True),
# fc7:Parameter containing:
# tensor([[ 0.0000, -0.0149, -0.0388,  ..., -0.0012, -0.0024, -0.0438],
#         [-0.0777,  0.0000, -0.0054,  ..., -0.0002, -0.0392, -0.0555],
#         [-0.0401, -0.0223,  0.0000,  ..., -0.0215, -0.0297, -0.0066],
#         ...,
#         [-0.0607, -0.0132,  0.0000,  ...,  0.0000, -0.0305, -0.0067],
#         [-0.0238, -0.0220, -0.0007,  ..., -0.0099,  0.0000, -0.0105],
#         [-0.0431, -0.0203, -0.0224,  ..., -0.0023, -0.0670,  0.0000]],
#        requires_grad=True),
# fc8:Parameter containing:
# tensor([[ 0.0180, -0.0118, -0.0689,  ..., -0.0320,  0.0240,  0.0924],
#         [ 0.0906,  0.0649, -0.0529,  ...,  0.0169,  0.0598, -0.1491],
#         [-0.0640,  0.0318,  0.0682,  ..., -0.0190, -0.0546, -0.0814],
#         ...,
#         [-0.0237,  0.0268,  0.0774,  ...,  0.0351, -0.0336, -0.0109],
#         [ 0.0303, -0.0441, -0.0482,  ...,  0.0049,  0.1392,  0.0238],
#         [ 0.0379,  0.0680,  0.0657,  ..., -0.0367,  0.0398, -0.0176]],
#        requires_grad=True)
#
#
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 286:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 74.22%
# Test set accuracy for a single minibatch: 70.31%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 287:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 78.91%
# Test set accuracy for a single minibatch: 68.75%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 288:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 70.31%
# Test set accuracy for a single minibatch: 72.66%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 289:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 78.91%
# Test set accuracy for a single minibatch: 73.44%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 290:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 74.22%
# Test set accuracy for a single minibatch: 67.19%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 291:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 78.12%
# Test set accuracy for a single minibatch: 76.56%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 292:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 67.97%
# Test set accuracy for a single minibatch: 71.88%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 293:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 71.09%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 294:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 76.56%
# Test set accuracy for a single minibatch: 66.41%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 295:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 68.75%
# Test set accuracy for a single minibatch: 71.88%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 296:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.78%
# Test set accuracy for a single minibatch: 72.66%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 297:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.78%
# Test set accuracy for a single minibatch: 69.53%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 298:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 70.31%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 299:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 68.75%
# Test set accuracy for a single minibatch: 69.53%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 300:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 69.53%
# Test set accuracy for a single minibatch: 67.97%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 301:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 77.34%
# Test set accuracy for a single minibatch: 75.00%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 302:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 68.75%
# Test set accuracy for a single minibatch: 76.56%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 303:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 72.66%
# Test set accuracy for a single minibatch: 73.44%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 304:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 67.97%
# Test set accuracy for a single minibatch: 74.22%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 305:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 82.03%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 306:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 82.03%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 307:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 74.22%
# Test set accuracy for a single minibatch: 68.75%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 308:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 68.75%
# Test set accuracy for a single minibatch: 76.56%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 309:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 74.22%
# Test set accuracy for a single minibatch: 75.00%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 310:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 72.66%
# Test set accuracy for a single minibatch: 75.78%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 311:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 67.97%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 312:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 78.12%
# Test set accuracy for a single minibatch: 66.41%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 313:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.78%
# Test set accuracy for a single minibatch: 67.97%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 314:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 64.84%
# Test set accuracy for a single minibatch: 64.84%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 315:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 67.19%
# Test set accuracy for a single minibatch: 71.88%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 316:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 72.66%
# Test set accuracy for a single minibatch: 73.44%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 317:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 70.31%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 318:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.09%
# Test set accuracy for a single minibatch: 68.75%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 319:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.78%
# Test set accuracy for a single minibatch: 71.88%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 320:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 71.88%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 321:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 67.97%
# Test set accuracy for a single minibatch: 69.53%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 322:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 72.66%
# Test set accuracy for a single minibatch: 68.75%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 323:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 82.03%
# Test set accuracy for a single minibatch: 75.78%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 324:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 67.97%
# Test set accuracy for a single minibatch: 65.62%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 325:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 72.66%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 326:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.78%
# Test set accuracy for a single minibatch: 74.22%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 327:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 72.66%
# Test set accuracy for a single minibatch: 66.41%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 3, Iteration 328:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# ...
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 72.66%
# Test set accuracy for a single minibatch: 77.34%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 354:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 77.34%
# Test set accuracy for a single minibatch: 74.22%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 355:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 67.97%
# Test set accuracy for a single minibatch: 68.75%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 356:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 67.19%
# Test set accuracy for a single minibatch: 71.88%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 357:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.78%
# Test set accuracy for a single minibatch: 80.47%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 358:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 75.00%
# Test set accuracy for a single minibatch: 78.91%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 359:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 76.56%
# Test set accuracy for a single minibatch: 71.88%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 360:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 78.12%
# Test set accuracy for a single minibatch: 72.66%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 361:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 73.44%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 362:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 74.22%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 363:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 74.22%
# Test set accuracy for a single minibatch: 78.12%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 364:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 79.69%
# Test set accuracy for a single minibatch: 70.31%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 365:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 78.91%
# Test set accuracy for a single minibatch: 75.00%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 366:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.09%
# Test set accuracy for a single minibatch: 73.44%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 367:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 74.22%
# Test set accuracy for a single minibatch: 68.75%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 368:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 67.97%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 369:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 77.34%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 370:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 68.75%
# Test set accuracy for a single minibatch: 73.44%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 371:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 69.53%
# Test set accuracy for a single minibatch: 65.62%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 372:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 66.41%
# Test set accuracy for a single minibatch: 72.66%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 373:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 69.53%
# Test set accuracy for a single minibatch: 78.12%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 374:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 72.66%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 375:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 74.22%
# Test set accuracy for a single minibatch: 71.09%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 376:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 73.44%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 377:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 70.31%
# Test set accuracy for a single minibatch: 82.81%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 378:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 73.44%
# Test set accuracy for a single minibatch: 75.78%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 4, Iteration 379:
#
# data size: torch.Size([128, 1, 28, 28])
# mem_rec (model output) size: torch.Size([25, 128, 10])
# targets size: torch.Size([128])
# Train set accuracy for a single minibatch: 69.53%
# Test set accuracy for a single minibatch: 75.78%
# Epoch 4, Iteration 379
# Train Set Loss: 12.58
# Test Set Loss: 10.46
# fc1:Parameter containing:
# tensor([[2.0457e-02, 7.9412e-03, 2.9615e-05,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [2.9336e-02, 1.5162e-02, 5.1821e-04,  ..., 5.4981e-02, 6.2139e-02,
#          2.2405e-02],
#         [4.7003e-03, 3.3844e-02, 6.6454e-02,  ..., 1.0490e-01, 1.1863e-01,
#          4.2818e-02],
#         ...,
#         [4.1213e-02, 7.7200e-03, 1.3268e-03,  ..., 2.9559e-02, 0.0000e+00,
#          5.7051e-05],
#         [2.6868e-03, 7.7006e-03, 0.0000e+00,  ..., 1.9504e-03, 2.6880e-03,
#          8.6467e-04],
#         [2.1397e-02, 3.5235e-02, 2.2602e-02,  ..., 0.0000e+00, 0.0000e+00,
#          6.9411e-03]], requires_grad=True),
# fc2:Parameter containing:
# tensor([[0.0523, 0.0445, 0.0189,  ..., 0.0465, 0.0931, 0.0322],
#         [0.0081, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0004],
#         [0.0000, 0.0003, 0.0033,  ..., 0.0749, 0.0479, 0.0041],
#         ...,
#         [0.0266, 0.0271, 0.0160,  ..., 0.0053, 0.0257, 0.0278],
#         [0.0000, 0.0222, 0.0448,  ..., 0.0445, 0.0406, 0.0000],
#         [0.0000, 0.0040, 0.0028,  ..., 0.0634, 0.0349, 0.0724]],
#        requires_grad=True),
# fc3:Parameter containing:
# tensor([[-4.2387e-02, -4.0096e-02, -8.9046e-04,  ..., -2.4384e-03,
#          -6.4259e-04, -3.5459e-03],
#         [-2.9344e-04, -6.9773e-03, -2.2448e-04,  ..., -2.8382e-03,
#          -6.2493e-02, -6.9405e-04],
#         [-9.9889e-03, -1.5596e-02, -1.2293e-02,  ..., -2.6987e-02,
#          -4.3698e-02, -2.2647e-02],
#         ...,
#         [-4.0147e-02, -2.1851e-02, -2.8374e-02,  ..., -4.7482e-03,
#          -5.9691e-03, -5.3191e-03],
#         [-6.5286e-02, -9.9137e-03, -3.5353e-04,  ..., -6.9520e-02,
#          -7.0260e-06, -1.3282e-02],
#         [-3.3218e-02, -6.4558e-02, -6.7071e-03,  ...,  0.0000e+00,
#          -3.7898e-02, -1.4424e-02]], requires_grad=True),
# fc4:Parameter containing:
# tensor([[ 0.0000, -0.0699,  0.0000,  ..., -0.0874, -0.0155, -0.0235],
#         [-0.0104,  0.0000, -0.0438,  ..., -0.0269, -0.0151, -0.0908],
#         [-0.0044, -0.0284,  0.0000,  ..., -0.0728, -0.0324, -0.0136],
#         ...,
#         [-0.0513, -0.0755, -0.0559,  ...,  0.0000,  0.0000, -0.0014],
#         [-0.0425, -0.0028, -0.0651,  ..., -0.0147,  0.0000, -0.0565],
#         [-0.0061, -0.0709, -0.0028,  ..., -0.0630, -0.0303,  0.0000]],
#        requires_grad=True),
# fc5:Parameter containing:
# tensor([[9.1050e-03, 3.3056e-02, 1.9432e-02,  ..., 1.6578e-02, 3.0069e-02,
#          4.3875e-02],
#         [3.0979e-02, 3.7416e-02, 2.0610e-02,  ..., 5.0369e-02, 4.1287e-04,
#          5.1908e-03],
#         [7.0079e-04, 2.4494e-04, 3.0773e-03,  ..., 8.3918e-03, 2.0396e-06,
#          9.7634e-03],
#         ...,
#         [0.0000e+00, 6.7658e-02, 5.7973e-02,  ..., 2.6468e-02, 3.0223e-02,
#          3.4892e-03],
#         [1.0647e-04, 4.1268e-02, 1.8848e-02,  ..., 3.6756e-02, 4.8765e-03,
#          1.3085e-03],
#         [8.7069e-03, 8.1205e-03, 4.8334e-02,  ..., 2.5408e-03, 4.6375e-02,
#          2.1647e-02]], requires_grad=True),
# fc6:Parameter containing:
# tensor([[-5.3374e-03, -6.8630e-03, -6.7785e-05,  ..., -3.9018e-03,
#          -7.8316e-04, -5.2221e-02],
#         [-1.2270e-03, -1.9278e-02, -1.1297e-02,  ..., -7.5161e-04,
#          -6.7398e-03, -1.7815e-02],
#         [-8.6777e-03, -1.0327e-02, -7.4483e-02,  ..., -3.9556e-03,
#          -1.1793e-02, -4.8871e-02],
#         ...,
#         [-1.3252e-02, -5.0194e-02, -2.9925e-03,  ..., -1.4422e-03,
#          -5.5180e-03, -1.8804e-03],
#         [-8.8044e-04, -1.0930e-02, -1.9259e-02,  ..., -3.8933e-02,
#          -3.5643e-02, -5.0022e-02],
#         [ 0.0000e+00, -8.5341e-03, -8.1198e-03,  ..., -6.1214e-02,
#           0.0000e+00, -2.1315e-02]], requires_grad=True),
# fc7:Parameter containing:
# tensor([[ 0.0000e+00, -1.5019e-02, -3.8793e-02,  ..., -5.2057e-05,
#          -1.2137e-05, -4.3136e-02],
#         [-7.9997e-02,  0.0000e+00, -5.3850e-03,  ..., -1.1139e-03,
#          -3.9804e-02, -6.1291e-02],
#         [-4.0047e-02, -2.2045e-02,  0.0000e+00,  ..., -2.0980e-02,
#          -2.9774e-02, -6.0866e-03],
#         ...,
#         [-6.2608e-02, -1.4260e-02, -1.9133e-05,  ...,  0.0000e+00,
#          -3.6186e-02, -3.1176e-03],
#         [-2.7862e-02, -2.3615e-02, -6.6792e-04,  ..., -6.0387e-03,
#           0.0000e+00, -1.5506e-02],
#         [-4.5634e-02, -2.2631e-02, -2.2433e-02,  ..., -1.7632e-03,
#          -6.6288e-02,  0.0000e+00]], requires_grad=True),
# fc8:Parameter containing:
# tensor([[ 0.0222, -0.0143, -0.0761,  ..., -0.0320,  0.0282,  0.0974],
#         [ 0.1093,  0.0702, -0.0601,  ...,  0.0169,  0.0568, -0.1640],
#         [-0.0697,  0.0342,  0.0764,  ..., -0.0190, -0.0557, -0.0927],
#         ...,
#         [-0.0282,  0.0276,  0.0860,  ...,  0.0351, -0.0322, -0.0076],
#         [ 0.0297, -0.0521, -0.0563,  ...,  0.0049,  0.1555,  0.0326],
#         [ 0.0400,  0.0875,  0.0713,  ..., -0.0367,  0.0438, -0.0194]],
#        requires_grad=True)
#
#
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# ====================================================================================================================================================================

# %% [markdown]
# ## Plotting loss and accuracy of a single epoch

# %%
# Plot train and test LOSS for a SINGLE EPOCH
epoch_idx = 0  # Index of the epoch to plot
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(loss_hist[epoch_idx])
plt.plot(test_loss_hist[epoch_idx])
plt.title("Loss Curves for Epoch 1")
plt.legend(["Train Loss", "Test Loss"])
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.grid(True, linestyle=':', alpha=0.6)
plt.show()

# %%
# Plot train and test ACCURACY for a SINGLE EPOCH
epoch_idx = 0  # Index of the epoch to plot
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(accuracy_test[epoch_idx])
plt.plot(accuracy_train[epoch_idx])
plt.title("Accuracy Plot for Epoch 1")
plt.legend(["Train Accuracy", "Test Accuracy"])
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.grid(True, linestyle=':', alpha=0.6)
plt.show()

# %% [markdown]
# ## Plotting loss and accuracy for all epochs

# %%
# Plotting Loss
plt.figure(figsize=(15, 6))

# Plot Train Data in one color
for i in range(num_epochs):
    plt.plot(range(i * num_iterations, (i + 1) * num_iterations),
             loss_hist[i],
             color='blue')  # Fixed color for train

# Plot Test Data in another color
for i in range(num_epochs):
    plt.plot(range(i * num_iterations, (i + 1) * num_iterations),
             test_loss_hist[i],
             color='orange')  # Fixed color for test

# Add vertical grid lines for epoch boundaries
for i in range(0, num_epochs+1):
    plt.axvline(x=i * num_iterations, color='gray', linestyle='--')

plt.title(f"Loss for Each Epoch ({num_epochs} Epochs)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
epoch_ticks = [i * num_iterations for i in range(num_epochs + 1)]  # Epoch start points
epoch_labels = [f"{i}" for i in range(num_epochs + 1)]  # Labels
plt.xticks(epoch_ticks, epoch_labels)

# Legend for Train and Test
plt.plot([], [], color='blue', label='Train Loss')
plt.plot([], [], color='orange', label='Test Loss')
plt.legend()

plt.grid(True, linestyle=':', alpha=0.6)
plt.show()

# %%
# Plotting Accuracy
plt.figure(figsize=(15, 6))

# Plot Train Data in one color
for i in range(num_epochs):
    plt.plot(range(i * num_iterations, (i + 1) * num_iterations),
             accuracy_train[i],
             color='blue')  # Fixed color for train

# Plot Test Data in another color
for i in range(num_epochs):
    plt.plot(range(i * num_iterations, (i + 1) * num_iterations),
             accuracy_test[i],
             color='orange')  # Fixed color for test

# Add vertical grid lines for epoch boundaries
for i in range(0, num_epochs+1):
    plt.axvline(x=i * num_iterations, color='gray', linestyle='--')

plt.title(f"Accuracy for Each Epoch ({num_epochs} Epochs)")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
epoch_ticks = [i * num_iterations for i in range(num_epochs + 1)]  # Epoch start points
epoch_labels = [f"{i}" for i in range(num_epochs + 1)]  # Labels

plt.xticks(epoch_ticks, epoch_labels)
# Legend for Train and Test
plt.plot([], [], color='blue', label='Train Accuracy')
plt.plot([], [], color='orange', label='Test Accuracy')
plt.legend()

plt.grid(True, linestyle=':', alpha=0.6)
plt.show()

# %% [markdown]
# ## Calculating accuracy for the entire test split

# %%
#Using same method of accuracy calculation, calculate accuracy of entire test set.
total = 0
correct = 0
with torch.no_grad():
  model.eval()
  for data, targets in test_loader:
    data = data
    targets = targets

    #forward pass
    _,test_spk = model(data.view(data.size(0), -1))

    #calculate accuracy
    _, predicted = test_spk.sum(dim=0).max(1)
    total += targets.size(0)
    correct += (predicted == targets).sum().item()

print(f"Total correctly classified test set images: {correct}/{total}")
print(f"Test Set Accuracy: {100 * correct / total:.2f}%")
# Out:
# Total correctly classified test set images: 15479/20992
# Test Set Accuracy: 73.74%

# %% [markdown]
# ## Optional: Saving final weights and other important variables to google drive

# %%
checkpoint = {
    'model_state': model.state_dict(),
    'num_epochs':num_epochs,
    'num_iterations':num_iterations,
    'optimizer_state': optimizer.state_dict(),
    'accuracy_train': accuracy_train,
    'accuracy_test': accuracy_test,
    'loss_hist': loss_hist,
    'test_loss_hist': test_loss_hist,
}
#torch.save(checkpoint, "/content/drive/My Drive/Noise_Final.pth")
